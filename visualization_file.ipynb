# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('cars.csv')
data.head()
# Out:
#     mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0  14.0          8         350  165      4209          12  1972       US.
# 1  31.9          4          89   71      1925          14  1980   Europe.
# 2  17.0          8         302  140      3449          11  1971       US.
# 3  15.0          8         400  150      3761          10  1971       US.
# 4  30.5          4          98   63      2051          17  1978       US.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  261 non-null    object
#  3   hp           261 non-null    int64
#  4   weightlbs    261 non-null    object
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
data['cubicinches'] = pd.to_numeric(data['cubicinches'], errors = 'coerce')
data['weightlbs'] = pd.to_numeric(data['weightlbs'], errors = 'coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %% [markdown]
# Question 1 Create scatter plots for the following data, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.
#
# 1.‘hp’ and ‘mpg’.
#
# 2.‘hp’ and ‘time-to-60’.
#
# 3.‘hp’ and ‘weightlbs’.
#
# 4.‘hp’ and ‘cylinders’.
#
# 5.Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60) with respect to each brand.

# %%
#example
x = [5,7,8,2,3,4]
y = [2,3,5,7,3,2]

sns.scatterplot(x = x,y = y,color = 'red')
plt.title("Scatter plot")
plt.xlabel("x values")
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %%
fig, axes = plt.subplots(2,2,figsize=(15,10))

plt.subplot(2,2,1)
sns.scatterplot(x = data['mpg'], y = data['hp'], data=data)
plt.title('MPG to HP data')
plt.xlabel("Miles per Gallon")
plt.ylabel("Horsepower")

plt.subplot(2,2,2)
sns.scatterplot(x=data['hp'], y=data['time-to-60'], data=data)
plt.title('HP to Time-to-60 data')
plt.xlabel("Horsepower")
plt.ylabel("Time-to-60")

plt.subplot(2,2,3)
sns.scatterplot(x=data['hp'], y=data['weightlbs'], data=data)
plt.title('HP to Weight Data')
plt.xlabel("Horsepower")
plt.ylabel("Weightlbs")


plt.subplot(2,2,4)
sns.scatterplot(x=data['hp'], y=data['cylinders'], data=data)
plt.title('HP to Cylinders data')
plt.xlabel("Horsepower")
plt.ylabel("No of Cylinders")
# Out:
# Text(0, 0.5, 'No of Cylinders')

# %%
sns.scatterplot(x = data['mpg'], y = data['hp'], data=data, hue = data["brand"])
plt.title('MPG to HP data')
plt.xlabel("Miles per Gallon")
plt.ylabel("Horsepower")
# Out:
# Text(0, 0.5, 'Horsepower')

# %%
data["brand"].unique()
# Out:
# array([' US.', ' Europe.', ' Japan.'], dtype=object)

# %%
fig, axes = plt.subplots(2,2, figsize=(20,10))


plt.subplot(2,2,1)
sns.scatterplot(x=data['mpg'], y=data['hp'],hue=data['brand'], data=data)

plt.subplot(2,2,2)
sns.scatterplot(x=data['hp'], y=data['time-to-60'], hue=data['brand'], data=data)

plt.subplot(2,2,3)
sns.scatterplot(x=data['hp'], y=data['mpg'], hue=data['brand'], data=data)

plt.subplot(2,2,4)
sns.scatterplot(x=data['mpg'], y=data['weightlbs'], hue=data['brand'], data=data)
# Out:
# <Axes: xlabel='mpg', ylabel='weightlbs'>

# %% [markdown]
# Question 2 Create bar plots for the following, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.
#
# 1. Cylinders and Horsepower, Cylinders and miles per gallon, Cylinders and weight.
#
# 2. Year and time-to-60, Year and miles per gallon, Year and horsepower.
#
# 3. Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands.
#
# 4. Create a bar plot that shows the visual representation of hp, mpg, weight and time-to-60 with respect to the years, for each bra

# %%
#Example
x = [5,7,8,2,3,4]
y = [2,3,5,7,3,2]

plt.bar(x, y)
plt.title("Scater plot")
plt.xlabel("x values")
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %%
fig,axes = plt.subplots(2,2,figsize = (15,10))

plt.subplot(2,2,1)
sns.barplot(x = data["cylinders"], y = data["hp"], data = data, hue = data["brand"])
plt.title("Hp v/s cyllinders")
plt.xlabel("hp")
plt.ylabel("cylinders")


plt.subplot(2,2,2)
sns.barplot(x = data['cylinders'], y = data['mpg'], data=data, hue=data['brand'])   
plt.title('cylinders vs mpg')
plt.xlabel('cylinders')
plt.ylabel('mpg')

plt.subplot(2,2,3)
sns.barplot(x = data['cylinders'], y = data['weightlbs'], data=data, hue=data['brand'])  
plt.title('cylinders vs weightlbs')
plt.xlabel('hp')
plt.ylabel('weightlbs')

plt.subplot(2,2,4)
sns.barplot(x = data['cylinders'],y =  data['time-to-60'], data=data, hue=data['brand'])   
plt.title('cylinders vs time-to-60')
plt.ylabel('time-to-60')
plt.xlabel('cylinders')
# Out:
# Text(0.5, 0, 'cylinders')

# %%
plt.bar(data["cylinders"],data["hp"])
plt.title("Hp v/s cyllinders")
plt.xlabel("hp")
plt.ylabel("cylinders")
# Out:
# Text(0, 0.5, 'cylinders')

# %% [markdown]
# Question 3 Create box plots for the following:
#
# 1.Create box plots for the columns hp, mpg, time-to-60, and weight lbs.
#
# 2.Create box plots for the columns in the step1 with respect to the number of cylinders and brand respectively.

# %%
#example
np.random.seed(10)
data1 = np.random.normal(100,20,200)
fig = plt.figure(figsize = (10,7))
plt.boxplot(data1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#1,2,3,4,5,7,9,1000 ------------1000 is my outlier
#0.01,1,2,3,4,5,100 ------------0.01,100 is my outliers

# %%
fig, axes = plt.subplots(2,2,figsize = (20,10))

plt.subplot(2,2,1)
sns.boxplot(data["hp"])
plt.title("horsepower")

plt.subplot(2,2,2)
sns.boxplot(data["mpg"])
plt.title("Miles per gallon")

plt.subplot(2,2,3)
sns.boxplot(data["weightlbs"])
plt.title("Weightlbs")

plt.subplot(2,2,4)
sns.boxplot(data["time-to-60"])
plt.title("Time to 60")
# Out:
# Text(0.5, 1.0, 'Time to 60')

# %%
fig, axes = plt.subplots(2,2,figsize = (20,10))

plt.subplot(2,2,1)
sns.boxplot(data["hp"])
plt.title("horsepower")

plt.subplot(2,2,2)
sns.boxplot(data["mpg"])
plt.title("Miles per gallon")

plt.subplot(2,2,3)
sns.boxplot(data["weightlbs"])
plt.title("Weightlbs")

plt.subplot(2,2,4)
sns.boxplot(data["time-to-60"])
plt.title("Time to 60")
# Out:
# Text(0.5, 1.0, 'Time to 60')

# %% [markdown]
# Question 4
#
# Create pair plots for the entire data to study various patterns in the data.
#
# 1.Create pair plots with respect to brand, number of cylinders, year, etc.

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue = "brand")

# %%
sns.pairplot(data, hue = "year")

# %% [markdown]
# Question 5
# Create a heatmap for the entire data to study correlation between each of the columns.

# %%
#example
data2 = np.random.randint(1,100,size= (10,10))
hm = sns.heatmap(data = data2)
hm
# Out:
# <Axes: >

# %%
corr = data.corr()
corr
# Out:
# <ipython-input-41-df690e1cacaf>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
#                   mpg  cylinders  cubicinches        hp  weightlbs  \
# mpg          1.000000  -0.776710    -0.803964 -0.774905  -0.825234
# cylinders   -0.776710   1.000000     0.951452  0.845155   0.896093
# cubicinches -0.803964   0.951452     1.000000  0.906902   0.930027
# hp          -0.774905   0.845155     0.906902  1.000000   0.861028
# weightlbs   -0.825234   0.896093     0.930027  0.861028   1.000000
# time-to-60   0.509070  -0.578161    -0.613199 -0.744873  -0.480772
# year         0.550441  -0.322239    -0.350293 -0.383869  -0.281119
#
#              time-to-60      year
# mpg            0.509070  0.550441
# cylinders     -0.578161 -0.322239
# cubicinches   -0.613199 -0.350293
# hp            -0.744873 -0.383869
# weightlbs     -0.480772 -0.281119
# time-to-60     1.000000  0.312311
# year           0.312311  1.000000

# %%
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(corr, annot = True, cmap = "rainbow")
# Out:
# <Axes: >

# %% [markdown]
# Question 6 Create a histogram for the following:
#
# Each column in the data to understand the distribution of the data. Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with respect to brand.

# %%
#example

a = np.array([22,34,22,45,67,56,54,34,35])
plt.hist(a, bins = [0,25,50,75])
# Out:
# (array([2., 4., 3.]),
#  array([ 0., 25., 50., 75.]),
#  <BarContainer object of 3 artists>)

# %%
fig, axes = plt.subplots(4,2,figsize = (20,10))

plt.subplot(4,2,1)
plt.hist(data["hp"])

plt.subplot(4,2,2)
plt.hist(data["mpg"])

plt.subplot(4,2,3)
plt.hist(data["time-to-60"])

plt.subplot(4,2,4)
plt.hist(data["cylinders"])

plt.subplot(4,2,5)
plt.hist(data["weightlbs"])

plt.subplot(4,2,6)
plt.hist(data["cubicinches"])

plt.subplot(4,2,7)
plt.hist(data["year"])

plt.subplot(4,2,8)
plt.hist(data["brand"])
# Out:
# (array([162.,   0.,   0.,   0.,   0.,  48.,   0.,   0.,   0.,  51.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(x = data["hp"], hue = data["brand"])
# Out:
# <Axes: xlabel='hp', ylabel='Count'>

# %% [markdown]
# Question 7
# Create line plots for the following:
#
# Create a line plot for the columns hp, mpg, time-to-60, weight lbs in a single plot, where each line is a different color. [red, green, blue, orange]. Line plot between hp-mpg, hp-(time-to-60), mpg-(time-to-60), hp-weight lbs, mpg-weight lbs, cubic inches-weight lbs.

# %%
#Example
x = [5,7,8,2,3,4]
y = [2,3,5,7,3,2]
sns.lineplot(x= x,y =y)
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2,2, figsize = (20,10))

plt.subplot(2,2,1)
sns.lineplot(data = data , x = 'hp', y = 'mpg' )

plt.subplot(2,2,2)
sns.lineplot(data = data , x = 'hp', y = 'time-to-60' )

plt.subplot(2,2,3)
sns.lineplot(data = data , x = 'mpg', y = 'time-to-60' )

plt.subplot(2,2,4)
sns.lineplot(data = data , x = 'hp', y = 'weightlbs' )
# Out:
# <Axes: xlabel='hp', ylabel='weightlbs'>

# %% [markdown]
# Question 8 Create a pie chart for the following columns and their distribution in the data:
#
# Brands
#
# Cylinders

# %%
#Example
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
data["brand"].value_counts()
# Out:
#  US.        162
#  Japan.      51
#  Europe.     48
# Name: brand, dtype: int64

# %%
plt.pie(data["brand"].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9e65baec20>,
#   <matplotlib.patches.Wedge at 0x7f9e65badb70>,
#   <matplotlib.patches.Wedge at 0x7f9e65bad240>],
#  [Text(-0.40715189169477184, 1.0218744233463175, ''),
#   Text(-0.21703386613009362, -1.0783766971483688, ''),
#   Text(0.921454322290154, -0.6007677853653549, '')])

# %%
plt.pie(data["brand"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-770d00d95168> in <cell line: 1>()
# ----> 1 plt.pie(data["brand"])
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3189         # The use of float32 is "historical", but can't be changed without
#    3190         # regenerating the test baselines.
# -> 3191         x = np.asarray(x, np.float32)
#    3192         if x.ndim > 1:
#    3193             raise ValueError("x must be 1D")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     891               dtype='datetime64[ns]')
#     892         """
# --> 893         return np.asarray(self._values, dtype)
#     894
#     895     # ----------------------------------------------------------------------
#
# ValueError: could not convert string to float: ' US.'

# %%
plt.pie(data["brand"].value_counts(), labels = ["us","eu","jp"], explode = [0.4,0.2,0.2])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9e65bcfa90>,
#   <matplotlib.patches.Wedge at 0x7f9e65bced40>,
#   <matplotlib.patches.Wedge at 0x7f9e65bccb20>],
#  [Text(-0.5552071250383253, 1.3934651227449784, 'us'),
#   Text(-0.2564945690628379, -1.2744451875389813, 'eu'),
#   Text(1.0889914717974547, -0.7099982917954194, 'jp')])

# %% [markdown]
# Question 9 Create categorical plots for the following:
#
# Hp, mpg, time-to-60, weight, cubic inches, with respect to each brand for various numbers of cylinders.

# %%
sns.catplot( x = "cylinders", y = "hp", hue = "brand", data = data)

# %% [markdown]
# Question 10 In the Barplots created in step 2, do the following:
#
# Keep the color combination distinct for each of the bars in the plot. Change the size of the plots to - (20, 15) Change the font color to Red and Font size to 28 in the plots.

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='cylinders', y='hp', data=data)
plt.xlabel("Number of Cylinders in the Car", fontsize=28, color='Red')
plt.ylabel("Horsepower", fontsize=28, color='Red')
plt.show()
